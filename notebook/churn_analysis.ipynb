# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel('../data/customer_retention.xlsx')
df.head()
# Out:
#    customer_id signup_date last_active        plan  monthly_fee  usage_score  \
# 0            2  2025-02-11  2025-04-17         Pro           21           47
# 1            5  2025-11-01  2025-12-23       Basic           15           27
# 2            8  2025-01-28  2025-03-06  Enterprise           60           88
# 3           11  2025-07-18  2025-10-11       Basic          178           52
# 4           12  2025-04-27  2025-12-06         Pro          100           97
#
#    support_tickets payment_method        country  churn  tenure_days
# 0                0           Bank      Venezuela      0           65
# 1                5         Paypal          China      1           52
# 2                4           Card         Serbia      0           37
# 3                4           Bank          Chile      1           85
# 4               13         Paypal  United States      0          223

# %%
df.shape
# Out:
# (493, 11)

# %%
df.columns
# Out:
# Index(['customer_id', 'signup_date', 'last_active', 'plan', 'monthly_fee',
#        'usage_score', 'support_tickets', 'payment_method', 'country', 'churn',
#        'tenure_days'],
#       dtype='object')

# %%
df['churn'].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: churn, dtype: int64

# %%
df['churn'].value_counts()
# Out:
# churn
# 1    260
# 0    233
# Name: count, dtype: int64

# %%
df['churn'].value_counts(normalize=True) * 100
# Out:
# churn
# 1    52.738337
# 0    47.261663
# Name: proportion, dtype: float64

# %%
df['churn_label'] = df['churn'].map({0: 'Retained', 1: 'Churned'})
df[['churn', 'churn_label']].head()
# Out:
#    churn churn_label
# 0      0    Retained
# 1      1     Churned
# 2      0    Retained
# 3      1     Churned
# 4      0    Retained

# %%
churn_rate = round(df['churn'].mean() * 100, 2)
churn_rate
# Out:
# np.float64(52.74)

# %%
revenue_lost = df[df['churn'] == 1]['monthly_fee'].sum()
revenue_lost
# Out:
# np.int64(27357)

# %%
df.groupby('churn_label')['tenure_days'].mean()
# Out:
# churn_label
# Churned     119.638462
# Retained    124.553648
# Name: tenure_days, dtype: float64

# %%
df.groupby('churn_label')['usage_score'].mean()
# Out:
# churn_label
# Churned     51.261538
# Retained    48.751073
# Name: usage_score, dtype: float64

# %%
df.groupby('churn_label')['support_tickets'].mean()
# Out:
# churn_label
# Churned     6.850000
# Retained    7.515021
# Name: support_tickets, dtype: float64

# %%
df.groupby('plan')['churn'].mean().sort_values(ascending=False)
# Out:
# plan
# Enterprise    0.564706
# Basic         0.508772
# Pro           0.506579
# Name: churn, dtype: float64

# %%
df.groupby('payment_method')['churn'].mean().sort_values(ascending=False)
# Out:
# payment_method
# Bank      0.560811
# Card      0.538012
# Paypal    0.488506
# Name: churn, dtype: float64

# %%
high_risk_customers = df[
    (df['usage_score'] < 40) &
    (df['support_tickets'] > 3) &
    (df['tenure_days'] < 90)
]

high_risk_customers.head()
# Out:
#     customer_id signup_date last_active   plan  monthly_fee  usage_score  \
# 1             5  2025-11-01  2025-12-23  Basic           15           27
# 21           43  2025-07-16  2025-07-18  Basic          188           34
# 35           64  2025-07-06  2025-07-12    Pro           35           11
# 37           69  2025-11-06  2025-11-18  Basic          199           35
# 46           81  2025-10-31  2025-12-19  Basic           45           34
#
#     support_tickets payment_method    country  churn  tenure_days churn_label
# 1                 5         Paypal      China      1           52     Churned
# 21                9         Paypal   Colombia      0            2    Retained
# 35                7           Card  Argentina      0            6    Retained
# 37               15           Card    Ukraine      0           12    Retained
# 46               13           Bank   Bulgaria      0           49    Retained

# %%
high_risk_customers.shape
# Out:
# (76, 12)

# %%
high_risk_customers[['plan', 'monthly_fee', 'usage_score', 'support_tickets', 'tenure_days']].head()
# Out:
#      plan  monthly_fee  usage_score  support_tickets  tenure_days
# 1   Basic           15           27                5           52
# 21  Basic          188           34                9            2
# 35    Pro           35           11                7            6
# 37  Basic          199           35               15           12
# 46  Basic           45           34               13           49
